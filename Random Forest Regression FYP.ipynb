# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data_from_cst=pd.read_csv(r"C:\Jupyter Demo\optimized_antenna_dataset_v2.csv")
data_from_cst
# Out:
#       sl7l  sl2w      sl2l      sl7w  sl1l      sl1w   fl   fw        il  \
# 0      1.6   1.4  0.124908  0.128727  2.15  0.124728  1.8  0.4  0.749835
# 1      1.6   1.4  0.240143  0.144687  2.15  0.116582  1.8  0.4  0.873373
# 2      1.6   1.4  0.196399  0.220909  2.15  0.085231  1.8  0.4  0.781333
# 3      1.6   1.4  0.169732  0.118001  2.15  0.171453  1.8  0.4  0.541651
# 4      1.6   1.4  0.081204  0.223930  2.15  0.145325  1.8  0.4  0.592790
# ...    ...   ...       ...       ...   ...       ...  ...  ...       ...
# 4995   1.6   1.4  0.229479  0.221531  2.15  0.180177  1.8  0.4  0.938519
# 4996   1.6   1.4  0.073876  0.229502  2.15  0.085560  1.8  0.4  0.523407
# 4997   1.6   1.4  0.115569  0.239342  2.15  0.060248  1.8  0.4  0.651849
# 4998   1.6   1.4  0.213149  0.129498  2.15  0.186592  1.8  0.4  0.721660
# 4999   1.6   1.4  0.169462  0.093428  2.15  0.100216  1.8  0.4  0.586132
#
#             iw    k     ph        pl        pw   sh    sl   sw  Frequency_GHz  \
# 0     0.086500  6.7  0.035  2.592371  4.638145  0.8  5.22  6.0      32.187853
# 1     0.059226  6.7  0.035  2.560754  4.459292  0.8  5.22  6.0      20.778069
# 2     0.067332  6.7  0.035  3.104192  4.964499  0.8  5.22  6.0      32.245207
# 3     0.083164  6.7  0.035  3.466116  4.218978  0.8  5.22  6.0      21.793372
# 4     0.074104  6.7  0.035  3.002721  4.587856  0.8  5.22  6.0      34.206885
# ...        ...  ...    ...       ...       ...  ...   ...  ...            ...
# 4995  0.066374  6.7  0.035  3.452275  4.434404  0.8  5.22  6.0      35.080678
# 4996  0.086348  6.7  0.035  3.247824  4.463577  0.8  5.22  6.0      35.290539
# 4997  0.096164  6.7  0.035  2.519456  4.529667  0.8  5.22  6.0      25.391389
# 4998  0.081864  6.7  0.035  2.901005  4.967568  0.8  5.22  6.0      28.686395
# 4999  0.097592  6.7  0.035  2.757398  4.904692  0.8  5.22  6.0      29.748474
#
#           Gain
# 0     6.046148
# 1    -0.010114
# 2     4.335431
# 3     2.067697
# 4     2.821413
# ...        ...
# 4995  0.029028
# 4996  0.030028
# 4997 -0.014814
# 4998  6.019803
# 4999  5.231179
#
# [5000 rows x 19 columns]

# %%
x=data_from_cst.iloc[:,:-1]
y=data_from_cst.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
regress=RandomForestRegressor(n_estimators=100,max_depth=None,random_state=42,n_jobs=-1)
regress.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
y_pred=regress.predict(x_test)

# %%
#RMSE
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 0.16279903284769345

# %%
#MSE
print(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 0.026503525096144374

# %%
#MAE
from sklearn import metrics
print(metrics.mean_absolute_error(y_pred,y_test))
# Out:
# 0.1104332449425428

# %%
#R2 score
print(metrics.r2_score(y_pred,y_test))
# Out:
# 0.9966524582463109

# %%
#variance
print(metrics.explained_variance_score(y_pred,y_test))
# Out:
# 0.99667604731497
